# %% [markdown]
# <a href="https://colab.research.google.com/github/RamadaniOktavia/DIF62130_B_25_2311533002/blob/main/Praktikum1/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sample Dataset

# %%
import pandas as pd

data = {'luas' : [6, 8, 10, 14, 18],
        'harga' : [7, 9, 13, 17.5, 18]}
df = pd.DataFrame(data)
df
# Out:
#    luas  harga
# 0     6    7.0
# 1     8    9.0
# 2    10   13.0
# 3    14   17.5
# 4    18   18.0

# %% [markdown]
# PENJELASAN

# %% [markdown]
# # Visualisasi Data

# %%
import matplotlib.pyplot as plt

df.plot(kind='scatter', x='luas', y='harga')
plt.title('Perbandingan Luas tanah dengan Harga Tanah')
plt.xlabel('Luas tanah (m persegi)')
plt.ylabel('Harga Tanah (dollar)')
plt.xlim(0, 25)
plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %% [markdown]
# PENJELASAN

# %%
import numpy as np

X=np.array(df['luas'])    #Independent Variable (Target)
Y=np.array(df['harga'])   #Dependent Variable (Features)

print(f'x: {X}')
print(f'y: {Y}')
# Out:
# x: [ 6  8 10 14 18]
# y: [ 7.   9.  13.  17.5 18. ]

# %%
X = X.reshape(-1,1)
print(f'X shape: {X.shape}')
print(f'X: {X}')
# Out:
# X shape: (5, 1)
# X: [[ 6]
#  [ 8]
#  [10]
#  [14]
#  [18]]

# %% [markdown]
# PENJELASAN

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
X_vis = np.array([0, 25]).reshape(-1, 1)
y_vis = model.predict(X_vis)

# %%
plt.scatter(X, y)
plt.plot(X_vis, model.predict(X_vis), color='red')
plt.title('Perbandingan Luas tanah dengan Harga Tanah')
plt.xlabel('Luas tanah (m persegi)')
plt.ylabel('Harga Tanah (dollar)')
# plt.xlim(0, 25)
# plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %% [markdown]
# PENJELASAN

# %% [markdown]
# **Formula Linear Regression**
#
# y = a + bx
#
# y:respon variabel
#
# x:explanatory variable
#
# a:intercept
#
# b:slope

# %%
print(f'intercept: {model.intercept_}')
print(f'slope: {model.coef_}')
# Out:
# intercept: 1.965517241379315
# slope: [0.9762931]

# %% [markdown]
# PENJELASAN

# %% [markdown]
# **Prediksi Harga Tanah**

# %%
luas_tanah = np.array([12, 15, 20, 24]).reshape(-1,1)
print(luas_tanah.shape)
luas_tanah
# Out:
# (4, 1)
# array([[12],
#        [15],
#        [20],
#        [24]])

# %%
harga_prediksi = model.predict(luas_tanah)
harga_prediksi
# Out:
# array([13.68103448, 16.60991379, 21.49137931, 25.39655172])

# %%
for luas, hrg in zip(luas_tanah, harga_prediksi):
    print(f'Luas tanah {luas}: meter persegi dengan harga prediksi sebesar: {hrg}')
# Out:
# Luas tanah [12]: meter persegi dengan harga prediksi sebesar: 13.681034482758621
# Luas tanah [15]: meter persegi dengan harga prediksi sebesar: 16.609913793103445
# Luas tanah [20]: meter persegi dengan harga prediksi sebesar: 21.491379310344826
# Luas tanah [24]: meter persegi dengan harga prediksi sebesar: 25.39655172413793

# %% [markdown]
# # Evaluasi Simple Linear Regression Model

# %% [markdown]
# Training & Testing Dataset

# %%
X_train = np.array([6, 8, 10, 14, 18]).reshape(-1,1)
y_train = np.array([7, 9, 13, 17.5, 18])

# %%
X_test = np.array([9, 9, 11, 16, 12]).reshape(-1,1)
y_test = np.array([11, 8.5, 15, 18, 11])

# %% [markdown]
# Traoining Simple Linear Regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluasi linear regression Model dengan Coefficient of Determination atau R-square
#
# Ref: https://en.wikipedia.org/wiki/Coefficient_of_determination

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
r_squared = r2_score(y_test, y_pred)
print(f'R-squared: {r_squared}')
# Out:
# R-squared: 0.6873061136400747

# %%
y_pred
# Out:
# array([10.75215517, 10.75215517, 12.70474138, 17.5862069 , 13.68103448])

# %% [markdown]
# Nilai R-squared semakin mendekati 1 semakin baik
